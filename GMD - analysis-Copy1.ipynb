# %%
from data.distances.gmd import e2e_gmd
from data.distances.OCTADataset import OCTADataset

# %%
dataset = OCTADataset()

# %%
e2e_gmd(dataset, 355, 355, remove=3, C_V=1.0, C_E=10.0, multiplier=1.0, shift=0)
# Out:
# GMD execution time: 0.03 seconds
# GMD: 12.0, GED: 9.0

# %%
e2e_gmd(dataset, 355, 355, random_radius=0.1, C_V=1.0, C_E=10.0, multiplier=1.0, shift=0)
# Out:
# GMD execution time: 0.03 seconds
# GMD: 9.0, GED: 0.0

# %%
e2e_gmd(dataset, 355, 355, random_radius=0.3, remove=2, C_V=1.0, C_E=10.0, multiplier=1.0, shift=0)
# Out:
# GMD execution time: 0.11 seconds
# GMD: 20.0, GED: 6.0

# %%
e2e_gmd(dataset, 355, 355, random_radius=0.1, remove=2, C_V=10.0, C_E=1.0, multiplier=1.0, shift=0)
# Out:
# GMD execution time: 0.03 seconds
# GMD: 4.0, GED: 6.0

# %%
e2e_gmd(dataset, 1, 1, random_radius=0.1, remove=2, C_V=1.0, C_E=10.0, multiplier=1.0, shift=0)
# Out:
# GMD execution time: 0.01 seconds
# GMD: 11.0, GED: 2.0

# %%
e2e_gmd(dataset, 15, 14, C_V=1.0, C_E=10.0, multiplier=1.0, shift=1)
# Out:
# GMD execution time: 0.01 seconds
# GMD: 20.0, GED: 13.0

# %%
e2e_gmd(dataset, 826, 277, remove=3, random_radius=0.5, C_V=1.0, C_E=1.0, multiplier=100.0, shift=1)
# Out:
# GMD execution time: 0.04 seconds
# GMD: 5.58, GED: 33.0

# %%
e2e_gmd(dataset, 826, 12,random_radius=0.01, C_V=1.0, C_E=1.0, multiplier=100.0, shift=1)
# Out:
# GMD execution time: 0.04 seconds
# GMD: 5.89, GED: 29.0
