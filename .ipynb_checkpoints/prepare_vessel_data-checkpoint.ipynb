# %%
import pickle
from dump.forest import arterial_tree
from dump.forest import forest
import sys

sys.modules['arterial_tree'] = arterial_tree
sys.modules['forest'] = forest

# %%
forest_file = open('./dump/sample/VenousForest.pkl', 'rb')
forest = pickle.load(forest_file)

nodes = []
edges = []

for tree in forest.get_trees():
    for node in tree.get_tree_iterator(exclude_root=False, only_active=False):
        nodes.append(tuple(node.position))
    break

#print(nodes)

# %%
import pyvista
import numpy as np

plotter = pyvista.Plotter(shape=(1,2))

forest_file = open('./dump/sample/VenousForest.pkl', 'rb')
forest = pickle.load(forest_file)

#plotter = pyvista.Plotter()

nodes = []
edges = []

for tree in forest.get_trees():
    nodes.append(tuple(tree.root.position))
    for num, node in enumerate(tree.get_tree_iterator(exclude_root=False, only_active=False)):
        radius = node.radius
        position = node.position
        for i, child in enumerate(node.children):
            nodes.append(tuple(child.position * 1.5))
            edges.append([2, num + 1, num + i + 2])
    break

data = pyvista.PolyData(nodes, lines=edges)
data["My Labels"] = [f"P{i}" for i in range(data.n_points)]

plotter.subplot(0,1)
_ = plotter.add_mesh(data)
#plotter.add_point_labels(data, "My Labels", point_size=1, font_size=6)
plotter.show_bounds(show_zaxis=False, bounds=[0,1,0,1,0,1])
#plotter.add_lines(np.array([[0,1,1]]))

# Fix orientation for graph
plotter.camera_position = 'xy'
plotter.camera.roll -= 90
plotter.camera.zoom(2)

plotter.window_size = [1600, 800]
plotter.show(jupyter_backend="static")
# Out:
# <PIL.Image.Image image mode=RGB size=1600x800>

# %%
import pyvista
import os

plotter = pyvista.Plotter()

nodes = []
edges = []
# Plotting graph
for tree in forest.get_trees():
    for node in tree.get_tree_iterator(exclude_root=False, only_active=False):
        position = node.position
        nodes.append(tuple(node.position))
        print(radius)
    break

data = pyvista.PolyData()


_ = plotter.add_mesh(vtk_data)
plotter.show_bounds(show_zaxis=False, bounds=[0,1,0,1,0,1])

# Fix orientation for graph
plotter.camera_position = 'xy'
plotter.camera.roll -= 90
plotter.camera.zoom(3.5)


# Show everything
plotter.window_size = [1200, 400]
plotter.show(jupyter_backend="static")
# Out:
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# ...
