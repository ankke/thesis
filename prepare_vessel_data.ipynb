# %%
import pickle
from dump.forest import arterial_tree
from dump.forest import forest
import sys

sys.modules['arterial_tree'] = arterial_tree
sys.modules['forest'] = forest

# %%
forest_file = open('./dump/sample/VenousForest.pkl', 'rb')
forest = pickle.load(forest_file)

nodes = []
edges = []

for tree in forest.get_trees():
    for node in tree.get_tree_iterator(exclude_root=False, only_active=False):
        nodes.append(tuple(node.position))
    break

print(nodes)
# Out:
# [(0.0, 0.5462592605960767, 0.00267620105419445), (0.04455979674526236, 0.5399803662649937, 0.00267620105419445), (0.07497673780239379, 0.5260581084074308, 0.005632071749794758), (0.09541043588768516, 0.5037647975938755, 0.008788169561402066), (0.06390480748388697, 0.5037000518918756, 0.007173664954348791), (0.10707101963357539, 0.4763019657074994, 0.011922440048409345), (0.11852594181839227, 0.5033711896241743, 0.007197741351375474), (0.0487004568096472, 0.48244402240128237, 0.008398633509085023), (0.11559565107650192, 0.4479506363903928, 0.011988707411719163), (0.13072566942552777, 0.4694456229556628, 0.011075565394042093), (0.13017059875459647, 0.4914526728292473, 0.004530055603924098), (0.03380768700618296, 0.46132342918796587, 0.009384818621425322), (0.12123388306496452, 0.4192897934355425, 0.011201078418341214), (0.09977613102801307, 0.42904099612428176, 0.006114954577540426), (0.15868530383021187, 0.46237088170754054, 0.010521063866092879), (0.01585025682858861, 0.4433432908238233, 0.006560416505806086), (0.02203815985665168, 0.4660577929740467, 0.0017958030336320376), (0.12317593165337966, 0.39053342265213137, 0.01001778709191788), (0.07714316595944158, 0.4130834638575823, 0.0012035717618694456), (0.1830105299792194, 0.44757350729855777, 0.011220467496449319), (0.005403353325691529, 0.4205406241237803, 0.0033942758634947015), (0.01603945483425165, 0.4818292008828061, 0.0020052203914448573), (0.12254405341302982, 0.36210017215088824, 0.00849493520776601), (0.14266179236932586, 0.3810673608851728, 0.005514934930202737), (0.054154983205877805, 0.39764043806974286, -0.0009554434016906762), (0.1972423858708357, 0.4234017382836395, 0.009172179047597477), (0.19600760602514875, 0.4518337632029393, 0.009262297730629306), (0.01050885441649847, 0.4972331682570475, 0.006115679386794982), (0.1160818891364062, 0.3348137113754018, 0.006325807224043576), (0.0997460606978218, 0.35505703568419267, 0.008428655375347541), (0.153991740813039, 0.36872107782199776, 0.007506714985017536), (0.03475770041248688, 0.3782773626017136, 0.00035481922122961636), (0.20991398063564376, 0.4424447498879299, 0.007466525149494456), (0.10240812563683661, 0.31075588197250936, 0.003906308422480116), (0.12760066871194928, 0.316187148926182, 0.004407001083086781), (0.07235498370058108, 0.3549906253130443, 0.006808609054332858), (0.16661488013929276, 0.35778422075185046, 0.0099165149719781), (0.019417308690561068, 0.35634635960636757, 0.004664189128491555), (0.22393666089598155, 0.4333218737275843, 0.009680840817896247), (0.08417057942296337, 0.290260935806549, 0.0034071599078845036), (0.1064559435786707, 0.2969298927942611, 0.0012837715956125909), (0.14854257814875718, 0.29906647812648984, 0.0026219968616003108), (0.12203461303562513, 0.30165243748019666, 0.002170427745840789), (0.013370769616613404, 0.33049713560620897, 0.008232308186589987), (0.07273439821888258, 0.2657165223823297, 0.004692737089562486), (0.06318456495211731, 0.2867711634888253, 0.0069402527580080696), (0.11013504261136736, 0.2815213383180164, 0.00709809049469356), (0.17089098301639224, 0.2937012271595394, -0.0019263557503995162), (0.16849938293240938, 0.2943767156042413, -0.0014603726830365671), (0.12433580240420619, 0.28529772746376325, 0.005633607320783865), (0.010521957476049781, 0.3042094255364589, 0.009470294535072556), (0.07426169736895921, 0.24386379531475103, 0.005122142205000624), (0.07495040540515553, 0.24288362472061328, 0.005103521406986811), (0.11739394039818477, 0.2662978130393041, 0.0065339043472697035), (0.19585690352168733, 0.2849143428499876, -0.0014956366118292295), (0.1760200348658475, 0.2725397621198269, 0.0030011011252960547), (0.006826458427361175, 0.2783119630894636, 0.009074892615592219), (0.08392547304610384, 0.2180028888959717, 0.004059880095380889), (0.06241651298076623, 0.2230406507601023, 0.004266125426094055), (0.12452076676369168, 0.2510194450602694, 0.005795363317181991), (0.17501273683091115, 0.24748573234099813, 0.00933573242376521), (0.013550315323306403,  ...

# %%
import pyvista

forest_file = open('./dump/sample/VenousForest.pkl', 'rb')
forest = pickle.load(forest_file)

#plotter = pyvista.Plotter()

nodes = []
edges = []

for tree in forest.get_trees():
    nodes.append(tuple(tree.root.position))
    for num, node in enumerate(tree.get_tree_iterator(exclude_root=False, only_active=False)):
        radius = node.radius
        position = node.position
        for i, child in enumerate(node.children):
            nodes.append(tuple(child.position))
            edges.append([num + 1, num + i + 2])
        if num > 20:
            break
    break

print(nodes)
print(edges)

data = pyvista.PolyData(nodes, lines=edges)

print(data)

#pyvista.plot(data, notebook=True, jupyter_backend="static")

#_ = plotter.add_mesh(data)

#plotter.show_bounds(show_zaxis=False, bounds=[0,1,0,1,0,1])

#plotter.show(jupyter_backend="static")
# Out:
# [(0.0, 0.5462592605960767, 0.00267620105419445), (0.04455979674526236, 0.5399803662649937, 0.00267620105419445), (0.07497673780239379, 0.5260581084074308, 0.005632071749794758), (0.09541043588768516, 0.5037647975938755, 0.008788169561402066), (0.06390480748388697, 0.5037000518918756, 0.007173664954348791), (0.10707101963357539, 0.4763019657074994, 0.011922440048409345), (0.11852594181839227, 0.5033711896241743, 0.007197741351375474), (0.0487004568096472, 0.48244402240128237, 0.008398633509085023), (0.11559565107650192, 0.4479506363903928, 0.011988707411719163), (0.13072566942552777, 0.4694456229556628, 0.011075565394042093), (0.13017059875459647, 0.4914526728292473, 0.004530055603924098), (0.03380768700618296, 0.46132342918796587, 0.009384818621425322), (0.12123388306496452, 0.4192897934355425, 0.011201078418341214), (0.09977613102801307, 0.42904099612428176, 0.006114954577540426), (0.15868530383021187, 0.46237088170754054, 0.010521063866092879), (0.01585025682858861, 0.4433432908238233, 0.006560416505806086), (0.02203815985665168, 0.4660577929740467, 0.0017958030336320376), (0.12317593165337966, 0.39053342265213137, 0.01001778709191788), (0.07714316595944158, 0.4130834638575823, 0.0012035717618694456), (0.1830105299792194, 0.44757350729855777, 0.011220467496449319), (0.005403353325691529, 0.4205406241237803, 0.0033942758634947015), (0.01603945483425165, 0.4818292008828061, 0.0020052203914448573), (0.12254405341302982, 0.36210017215088824, 0.00849493520776601), (0.14266179236932586, 0.3810673608851728, 0.005514934930202737), (0.054154983205877805, 0.39764043806974286, -0.0009554434016906762), (0.1972423858708357, 0.4234017382836395, 0.009172179047597477), (0.19600760602514875, 0.4518337632029393, 0.009262297730629306), (0.01050885441649847, 0.4972331682570475, 0.006115679386794982)]
# [[1, 2], [2, 3], [3, 4], [3, 5], [4, 5], [4, 6], [5, 6], [6, 7], [6, 8], [7, 8], [8, 9], [9, 10], [9, 11], [10, 11], [12, 13], [12, 14], [13, 14], [14, 15], [15, 16], [16, 17], [17, 18], [18, 19], [18, 20], [19, 20], [20, 21], [20, 22], [22, 23]]
# PolyData (0x7f51bc5fe8c0)
#   N Cells:	8
#   N Points:	28
#   X Bounds:	0.000e+00, 1.972e-01
#   Y Bounds:	3.621e-01, 5.463e-01
#   Z Bounds:	-9.554e-04, 1.199e-02
#   N Arrays:	0

# %%
import pyvista
import os

plotter = pyvista.Plotter()

nodes = []
edges = []
# Plotting graph
for tree in forest.get_trees():
    for node in tree.get_tree_iterator(exclude_root=False, only_active=False):
        position = node.position
        nodes.append(tuple(node.position))
        print(radius)
    break

data = pyvista.PolyData()


_ = plotter.add_mesh(vtk_data)
plotter.show_bounds(show_zaxis=False, bounds=[0,1,0,1,0,1])

# Fix orientation for graph
plotter.camera_position = 'xy'
plotter.camera.roll -= 90
plotter.camera.zoom(3.5)


# Show everything
plotter.window_size = [1200, 400]
plotter.show(jupyter_backend="static")
# Out:
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# 0.0008
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [5], line 19
#      14     break
#      16 data = pyvista.PolyData()
# ---> 19 _ = plotter.add_mesh(vtk_data)
#      20 plotter.show_bounds(show_zaxis=False, bounds=[0,1,0,1,0,1])
#      22 # Fix orientation for graph
#
# NameError: name 'vtk_data' is not defined
